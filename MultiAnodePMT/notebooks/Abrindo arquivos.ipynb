# %%
#Loads file data
import matplotlib.pyplot as plt
import numpy as np
data_array=np.load('/home/creison/Documentos/TileCal/processed_data/cs10288/data_array_region2.npy')
#place to create the image
image_pathR = '/home/creison/Documentos/TileCal/image_apresentação'

# %%
print " A variância é: ",(data_array.var())
print "A variância da primeira coluna é: ",(data_array[:,0].var())
print "A média é: ",(data_array.mean())
print "A média é da primeira coluna é:: ",(data_array[:,0].mean())
print "O desvio padrão é: ",(data_array.std())
# Out:
#  A variância é:  21870.775
# A variância da primeira coluna é:  35180.656
# A média é:  205.21515
# A média é da primeira coluna é::  263.8909
# O desvio padrão é:  147.88771

# %%
#Find the dimension of an array
def dimensoes(matriz):
    tam_matriz = data_array.shape
    print('{} x {}'.format(tam_matriz[0], tam_matriz[1]))

dimensoes(data_array)
# Out:
# 165 x 48

# %%
#Scatter plot

plt.figure(figsize=(10,10))
scatter_plot = plt.scatter(data_array[:,1],data_array[:,7])
plt.title("Grafico de dispersao")
plt.xlabel("Canal 1")
plt.ylabel("Canal 2")
plt.show()

# %%
import pandas as pd
df = pd.DataFrame(data_array)
#Sets image size
plt.figure(figsize=(15,15))
plt.subplots(1,1)  
df.plot(kind='density',figsize=(17,15))

#plt.xlabel('Smarts')
#plt.ylabel('Probability')
plt.title('Histogram of IQ')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')


plt.savefig(image_pathR+'/Histograma.png', bbox_inches='tight',pad_inches = 0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-2ee3a72682f1> in <module>()
#      12
#      13
# ---> 14 plt.savefig(image_pathR+'/Histograma.png', bbox_inches='tight',pad_inches = 0)
#      15 plt.show()
#      16
#
# /home/creison/miniconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# /home/creison/miniconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ...

# %%
#Correlation chart between the 48 channels
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker

plt.figure(figsize=(15,15))
plt.subplots(1,1)
plt.matshow(np.corrcoef(data_array.transpose()),cmap='OrRd', fignum=1)
plt.colorbar()
plt.grid(False)
label_list=np.arange(0,48,1)
plt.xticks(label_list)
plt.yticks(label_list)
plt.savefig(image_pathR+'/Correlação48.png', bbox_inches='tight',pad_inches = 0)
plt.show()

# %%
DataX=np.zeros(165)
for i in range(47):
    DataX=DataX + data_array[:,i]

# %%
path="/home/creison/Documentos/TileCal/analysis_images/apresentação"

# %%
path="/home/creison/Documentos/TileCal/analysis_images/apresentação"

from matplotlib import pyplot as plt
plt.figure(figsize=(15,10))
plt.plot(data_array[:,7],label='Single-Anode PMT')
leg = plt.legend(bbox_to_anchor=(0.756, 0.999), loc="best", borderaxespad=0.,fontsize = 'x-large')

# hide tick and tick label of the big axes
plt.xlabel("Triggers",fontsize=15)
plt.ylabel("ADC Counts",fontsize=15)

#plt.savefig(path+'/Single Anode PMT.png', bbox_inches='tight')
# Out:
# Text(0,0.5,'ADC Counts')

# %%
from matplotlib import pyplot as plt
data_region='data_array_region1'
image_pathR = '/home/creison/Documentos/TileCal/image_apresentação' 
for i in range(47):
    plt.figure(figsize=(15,10))
    plt.plot(data_array[:,i],label=str(i))
    #plt.plot(data_array[:,43],label='Canal 44')
    #plt.plot(data_array[:,35],label='Canal 36')
    #plt.plot(data_array[:,31],label='Canal 32')

#plt.plot(data_array[:,25],label='Canal 26')

#a=data_array[:,3]
#b=data_array[:,35]
#c=data_array[:,31]


#plt.plot(np.sum([a,b], axis=0))
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig(image_pathR+'/Canal 44.png', bbox_inches='tight',pad_inches = 0)
    plt.show()

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

mu = data_array[:,33].mean()  
sigma = data_array[:,33].std() 
x = mu + sigma * data_array[:,33]

num_bins = 50

fig, ax = plt.subplots()

# Histogram of the data
n, bins, patches = ax.hist(x, num_bins, normed=1)

plt.figure(figsize=(15,10))
y = mlab.normpdf(bins, mu, sigma)
ax.plot(bins, y, '--')
ax.set_xlabel('X')
ax.set_ylabel('Probability')
ax.set_title('Histogram')

fig.tight_layout()
#fig.savefig(image_pathR+'/Histograma Canal 10.png')
plt.show()

# %%
data_array.shape
# Out:
# (165, 48)

# %%
#Sets image size
plt.figure(figsize=(15,10))
plt.plot(data_array)
plt.plot(data_array[:,7],label='Single-Anode PMT')

leg = plt.legend(bbox_to_anchor=(0.756, 0.999), loc="best", borderaxespad=0.,fontsize = 'x-large')

# hide tick and tick label of the big axes
plt.xlabel("Triggers",fontsize=15)
plt.ylabel("ADC Counts",fontsize=15)
plt.savefig(path+'/Multi_Anode PMT.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-57841d20d89e> in <module>()
#       9 plt.xlabel("Triggers",fontsize=15)
#      10 plt.ylabel("ADC Counts",fontsize=15)
# ---> 11 plt.savefig(path+'/Multi_Anode PMT.png', bbox_inches='tight')
#
# NameError: name 'path' is not defined

# %%
soma=np.zeros(165)
for num1 in range(48):
        soma=np.sum([soma,data_array[:,num1]], axis=0)

# %%
plt.figure(figsize=(15,10))
plt.plot(soma)
X=8.8*data_array[:,7]
plt.plot(X)

plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot()

plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(data_array[:,7],label='Single-Anode PMT')




plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig(image_pathR+'/Canal 44.png', bbox_inches='tight',pad_inches = 0)
plt.show()

# %%
data=data_array[35:112]

# %%
plt.figure(figsize=(15,10))
plt.plot(data,label='Single-Anode PMT')




plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig(image_pathR+'/Canal 44.png', bbox_inches='tight',pad_inches = 0)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
from sklearn.decomposition import FastICA
import heapq
import os
from decimal import Decimal
from sklearn.cluster import KMeans
import cPickle as pickle

# %%
home_path = os.getcwd().replace('/MultiAnodePMT/notebooks','')

# %%
file = open(home_path+'/processed_data/Dados_TMP/A12.CS10290F.EBA66.FULL.pkl','rb')
data_array_full = pickle.load(file)

# %%
plt.figure(figsize=(60,10))
plt.plot(data_array_full['data'])




#plt.savefig(image_pathR+'/Canal 44.png', bbox_inches='tight',pad_inches = 0)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
a = np.linspace(0,1,1000)
signala = np.sin(2*np.pi*100*a) # with frequency of 100
plt.plot(signala)

# %%
signalb = np.sin(2*np.pi*20*a) # frequency 20
plt.plot(signalb)

# %%
signalc = signala + signalb
plt.plot(signalc)

# %%
b, a = signal.butter(5, 30, 'low', analog = True) #first parameter is signal order and the second one refers to frequenc limit. I set limit 30 so that I can see only below 30 frequency signal component
output = signal.filtfilt(b, a, signalc)
plt.plot(output)

# %%
from scipy.signal import argrelmax
x = np.array([2, 1, 2, 3, 2, 0, 1, 0])
argrelmax(x)

y = np.array([[1, 2, 1, 2],
              [2, 2, 0, 0],
              [5, 3, 4, 4]])

argrelmax(y, axis=1)
# Out:
# (array([0]), array([1]))

# %%
argrelmax(y, axis=1)
# Out:
# (array([0]), array([1]))
