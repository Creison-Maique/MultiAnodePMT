# %%
# %run 'Opening Files.ipynb'

# %%
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import MDS
from sklearn.manifold import SpectralEmbedding
from sklearn.manifold import locally_linear_embedding
from sklearn.manifold import smacof
from sklearn.manifold import spectral_embedding

# %%
CalcLocallyLinearEmbedding=MDS(n_components=64)
S_= CalcLocallyLinearEmbedding.fit_transform(matriz_serpentina)  
    
myarray = np.asarray(S_)
myarray2= (myarray-myarray.min())/(myarray.max()-myarray.min())


components=myarray2

plt.style.use('ggplot')
plt.figure(figsize=(10,10))

plt.plot(components[:,0],components[:,1],'o')

plt.title('Scatter Plot', fontsize = 25)
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

#plt.axis('off')
# hide tick and tick label of the big axes
plt.xlabel("Component 1",fontsize=20)
plt.ylabel("Component 2",fontsize=20)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    
plt.show()

    
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


  

ax.scatter(components[:,0], components[:,1], components[:,2])

ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')

plt.show()

# %%
CalcMDS=MDS(n_components=64)
S_= CalcMDS.fit_transform(matriz_serpentina)  
    
myarray = np.asarray(S_)
myarray2= (myarray-myarray.min())/(myarray.max()-myarray.min())


components=myarray2

plt.style.use('ggplot')
plt.figure(figsize=(10,10))

plt.plot(components[:,0],components[:,1],'o')

plt.title('Scatter Plot', fontsize = 25)
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

#plt.axis('off')
# hide tick and tick label of the big axes
plt.xlabel("Component 1",fontsize=20)
plt.ylabel("Component 2",fontsize=20)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    

plt.show()

    
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


  

ax.scatter(components[:,0], components[:,1], components[:,2])

ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')

plt.show()

# %%
CalcSpectralEmbedding=SpectralEmbedding(n_components=64)
S_= CalcSpectralEmbedding.fit_transform(matriz_serpentina)  
    
myarray = np.asarray(S_)
myarray2= (myarray-myarray.min())/(myarray.max()-myarray.min())

components=myarray2


plt.style.use('ggplot')
plt.figure(figsize=(10,10))

plt.plot(components[:,0],components[:,1],'o')

plt.title('Scatter Plot', fontsize = 25)
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

#plt.axis('off')
# hide tick and tick label of the big axes
plt.xlabel("Component 1",fontsize=20)
plt.ylabel("Component 2",fontsize=20)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    

plt.show()

    
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


  

ax.scatter(components[:,0], components[:,1], components[:,2])

ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')

plt.show()

# %%
from sklearn.decomposition import KernelPCA

# %%
kernelPCA=KernelPCA(n_components=64,kernel="precomputed", gamma=10)
S_= kernelPCA.fit_transform(matriz_serpentina)  


myarray = np.asarray(S_)
myarray2= (myarray-myarray.min())/(myarray.max()-myarray.min())

components=myarray2


plt.style.use('ggplot')
plt.figure(figsize=(10,10))

plt.plot(components[:,0],components[:,1],'o')

plt.title('Scatter Plot', fontsize = 25)
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')

#plt.axis('off')
# hide tick and tick label of the big axes
plt.xlabel("Component 1",fontsize=20)
plt.ylabel("Component 2",fontsize=20)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    

plt.show()

    
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


  

ax.scatter(components[:,0], components[:,1], components[:,2])

ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d162653b14cc> in <module>()
#       1 kernelPCA=KernelPCA(n_components=64,kernel="precomputed", gamma=10)
# ----> 2 S_= kernelPCA.fit_transform(matriz_serpentina)
#       3
#       4
#       5 myarray = np.asarray(S_)
#
# /home/creison/miniconda2/lib/python2.7/site-packages/sklearn/decomposition/kernel_pca.pyc in fit_transform(self, X, y, **params)
#     260         X_new : array-like, shape (n_samples, n_components)
#     261         """
# --> 262         self.fit(X, **params)
#     263
#     264         X_transformed = self.alphas_ * np.sqrt(self.lambdas_)
#
# /home/creison/miniconda2/lib/python2.7/site-packages/sklearn/decomposition/kernel_pca.pyc in fit(self, X, y)
#     236         """
#     237         X = check_array(X, accept_sparse='csr', copy=self.copy_X)
# --> 238         K = self._get_kernel(X)
#     239         self._fit_transform(K)
#     240
#
# /home/creison/miniconda2/lib/python2.7/site-packages/sklearn/decomposition/kernel_pca.pyc in _get_kernel(self, X, Y)
#     164         return pairwise_kernels(X, Y, metric=self.kernel,
#     165                                 filter_params=True, n_jobs=self.n_jobs,
# --> 166                                 **params)
#     167
#     168     def _fit_transform(self, K):
#
# /home/creison/miniconda2/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in pairwise_kernels(X, Y, metric, filter_params, n_jobs, **kwds)
#    1389
#    1390     if metric == "precomputed":
# -> 1391         X, _ = check_pairwise_arrays(X, Y, precomputed=True)
#    1392         return X
#    1393     elif isinstance(metric, GPKernel):
#
# /home/creison/miniconda2/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in check_pairwise_arrays(X, Y, precomputed, dtype)
#     117                              "(n_queries, n_indexed). Got (%d, %d) "
#     118                              "for %d indexed." %
# --> 119                              (X.shape[0], X.shape[1], Y.shape[0]))
#     120     elif X.shape[1] != Y.shape[1]:
#     121         raise ValueError("Incompatible dimension for X and Y matrices: "
#
# ValueError: Precomputed metric requires shape (n_queries, n_indexed). Got (146, 64) for 146 indexed.
